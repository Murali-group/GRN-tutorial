# %% [markdown]
# # BEELINE
#
# Single-cell RNA-sequencing technology has made it possible to trace cellular lineages during differentiation and to identify new cell types. A central question that arises now is whether we can discover the gene regulatory networks (GRNs) that control cellular differentiation and drive transitions from one cell type to another. In such a GRN, each edge connects a transcription factor (TF) to a gene it regulates.
#
# ![beeline.png](attachment:beeline.png)
#
# We have developed BEELINE, a comprehensive evaluation framework to assess the accuracy, robustness and efficiency of GRN inference techniques for single-cell gene expression data based on well-defined benchmark datasets.  In this workshop we use BEELINE to the run 4 GRN inference algorithms PIDC, GRNBoost2, SINCERITIES, and SCODE on 4 datasets generated from synthetic networks and 4 datasets generated from curated models.

# %% [markdown]
# # Synthetic Networks
#
# To create synthetic datasets exhibiting diverse temporal trajectories, we use six ‘toy’ networks created in Dynverse, a comparison of pseudotime inference algorithms.  We manually convert each of these networks to a Boolean model: we set a node to be ‘on’ if and only if at least one activator is ‘on’ and every inhibitor is ‘off’. We simulate these networks using BoolODE.

# %% [markdown]
# ### Bifurcating Network
#
# A network that contains a mutual inhibition motif between two genes resulting in two distinct branches starting from a common trajectory.
#
# ![bf.png](attachment:bf.png)

# %%
# %run BLRunner.py --config config-files/Quickstart/Synthetic/dyn-BF-quickstart.yaml
# %run BLEvaluator.py --config config-files/Quickstart/Synthetic/dyn-BF-quickstart.yaml --auc --jaccard --epr
# Out:
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Evaluation started
# ...

# %% [markdown]
# ### Linear Network
#
# A gene activation cascade that results in a single temporal trajectory with distinct final and initial states.
#
# ![linear.png](attachment:linear.png)

# %%
# %run BLRunner.py --config config-files/Quickstart/Synthetic/dyn-LI-quickstart.yaml
# %run BLEvaluator.py --config config-files/Quickstart/Synthetic/dyn-LI-quickstart.yaml --auc --jaccard --epr
# Out:
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Evaluation started
# ...

# %% [markdown]
# ### Bifurcating Converging Network
#
# An initial bifurcation creates two branches, which ultimately converge to a single steady state.
#
# ![bfc.png](attachment:bfc.png)

# %%
# %run BLRunner.py --config config-files/Quickstart/Synthetic/dyn-BFC-quickstart.yaml
# %run BLEvaluator.py --config config-files/Quickstart/Synthetic/dyn-BFC-quickstart.yaml --auc --jaccard --epr
# Out:
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Evaluation started
# ...

# %% [markdown]
# ### Trifurcating Network
#
# Mutual inhibition motifs involving three genes in this network result in three distinct steady states.
#
# ![tf.png](attachment:tf.png)

# %%
# %run BLRunner.py --config config-files/Quickstart/Synthetic/dyn-TF-quickstart.yaml
# %run BLEvaluator.py --config config-files/Quickstart/Synthetic/dyn-TF-quickstart.yaml --auc --jaccard --epr
# Out:
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping SCNS
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Evaluation started
# ...

# %% [markdown]
# ### Synthetic Networks Performance

# %%
# %run BLPlotter.py --config config-files/Quickstart/Synthetic/dyn-BF-quickstart.yaml,config-files/Quickstart/Synthetic/dyn-LI-quickstart.yaml,config-files/Quickstart/Synthetic/dyn-BFC-quickstart.yaml,config-files/Quickstart/Synthetic/dyn-TF-quickstart.yaml  --epr --auprc --overview
# Out:
# Early Precision of a random predictor for  dyn-BF  network (excluding self loops) is: 0.24
# Early Precision of a random predictor for  dyn-LI  network (excluding self loops) is: 0.17
# Early Precision of a random predictor for  dyn-BFC  network (excluding self loops) is: 0.17
# Early Precision of a random predictor for  dyn-TF  network (excluding self loops) is: 0.30
#
#
# Generating AUPRC boxplot...
# /home/ismb2022-grn/anaconda3/envs/BEELINE/lib/python3.7/site-packages/pandas/core/indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# Boxplot saved to ./dyn-BF-dyn-LI-dyn-BFC-dyn-TF-boxplot-AUPRC.pdf
#
#
# Generating Early Precision boxplot...
# Boxplot saved to ./dyn-BF-dyn-LI-dyn-BFC-dyn-TF-boxplot-EPr.pdf
# ...

# %% [markdown]
# # Curated Models
#
# While the synthetic models presented above are useful for generating simulated data with a variety of specific trajectories, these networks do not correspond to any real cellular process. To create simulated datasets that better reflect the characteristics of single-cell transcriptomic datasets, we turned to published Boolean models of GRNs, as these models are reflective of the real ‘ground-truth’ control systems in biology.

# %% [markdown]
# ### Gonadal Sex Determination
#
# Rios et al. modeled the gonadal differentiation circuit that regulates the maturation of the bipotential gonadal primordium into either male (testes) or female (ovary) gonads. The model consists of 18 genes and a node representing the urogenital ridge, which serves as the input to the model. For the wildtype simulations, the Boolean model predominantly exhibits two steady states corresponding to the Sertoli cells (male gonad precursors) or the granulosa cells (female gonad precursors), and one rare state corresponding to a dysfunctional pathway.
#
# ![gsd.png](attachment:gsd.png)

# %%
# %run BLRunner.py --config config-files/Quickstart/Curated/GSD-quickstart.yaml
# %run BLEvaluator.py --config config-files/Quickstart/Curated/GSD-quickstart.yaml --auc --jaccard --epr
# Out:
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Evaluation started
# ...

# %% [markdown]
# ### Mammalian Cortical Area Development
#
# Giacomantonio et al. explored mCAD as a consequence of the expression of regulatory TFs along an anterior-posterior gradient. The model contains five TFs connected by 14 interactions, captures the expected gene expression patterns in the anterior and posterior compartments, respectively, and results in two steady states.
#
# ![mcad.png](attachment:mcad.png)

# %%
# %run BLRunner.py --config config-files/Quickstart/Curated/mCAD-quickstart.yaml
# %run BLEvaluator.py --config config-files/Quickstart/Curated/mCAD-quickstart.yaml --auc --jaccard --epr
# Out:
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Evaluation started
# ...

# %% [markdown]
# ### Hematopoietic Stem Cell
#
# Krumsiek et al. investigated the GRN underlying myeloid differentiation. The proposed model has 11 TFs and captures the differentiation of multipotent myeloid progenitor (CMP cells) into erythrocytes, megakaryocytes, monocytes and granulocytes. The Boolean model exhibits four steady states, each corresponding to one of the four cell types mentioned above.
#
# ![hsc.png](attachment:hsc.png)

# %%
# %run BLRunner.py --config config-files/Quickstart/Curated/HSC-quickstart.yaml
# %run BLEvaluator.py --config config-files/Quickstart/Curated/HSC-quickstart.yaml --auc --jaccard --epr
# Out:
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Evaluation started
# ...

# %% [markdown]
# ### Ventral Spinal Cord
#
# Lovrics et al. investigated the regulatory basis of VSC development. The model consisting of eight TFs involved in ventralization contains 15 interactions, all of which are inhibitory. It succeeds in accounting for five distinct neural progenitor cell types. We expect to see five steady states from this model.
#
# ![vsc.png](attachment:vsc.png)

# %%
# %run BLRunner.py --config config-files/Quickstart/Curated/VSC-quickstart.yaml
# %run BLEvaluator.py --config config-files/Quickstart/Curated/VSC-quickstart.yaml --auc --jaccard --epr
# Out:
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Skipping GRNVBEM
# Skipping GENIE3
# Skipping PPCOR
# Skipping SCNS
# Skipping LEAP
# Skipping GRISLI
# Skipping SINGE
# Skipping SCRIBE
# Evaluation started
# ...

# %% [markdown]
# ### Curated Networks Performance

# %%
# %run BLPlotter.py --config config-files/Quickstart/Curated/GSD-quickstart.yaml,config-files/Quickstart/Curated/mCAD-quickstart.yaml,config-files/Quickstart/Curated/HSC-quickstart.yaml,config-files/Quickstart/Curated/VSC-quickstart.yaml  --epr --auprc --overview
# Out:
# Early Precision of a random predictor for  GSD  network (excluding self loops) is: 0.22
# Early Precision of a random predictor for  mCAD  network (excluding self loops) is: 0.65
# Early Precision of a random predictor for  HSC  network (excluding self loops) is: 0.24
# Early Precision of a random predictor for  VSC  network (excluding self loops) is: 0.27
#
#
# Generating AUPRC boxplot...
# /home/ismb2022-grn/anaconda3/envs/BEELINE/lib/python3.7/site-packages/pandas/core/indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# Boxplot saved to ./GSD-mCAD-HSC-VSC-boxplot-AUPRC.pdf
#
#
# Generating Early Precision boxplot...
# Boxplot saved to ./GSD-mCAD-HSC-VSC-boxplot-EPr.pdf
#
#
# Generating overview plot...
# ...
